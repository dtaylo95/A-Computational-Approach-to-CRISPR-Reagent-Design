# %% [markdown]
# # **Welcome**!
# Our goal in this module is for you to
# 1.   get comfortable with Python
# 2.   start getting prepared to design your own CRISPR reagents
#
# Assessment will be based both effort and how well your code works, so please do your best and feel free to ask questions either in class, office hours, or via email.
#
# In addition to your usual TAs, Dylan Taylor (dtaylo95@jhu.edu) and Sara Carioscia (scarios1@jhu.edu), the grad students who created this module, are happy to work with you on this and any questions you may have. This was designed especially for *you* based on our experience as TAs last year, so we are grateful for any and all feedback and suggestions you have to improve the module.

# %% [markdown]
# This homework assignment is designed to give you practice with the concepts introduced in Intro to Python: creating and modifying variables and data structures, and manipulating data stored in those structures to produce new data. Our goal is that each exercise here will be a building block for the activities you'll do in the CRISPR design assignments.

# %% [markdown]
# # Manipulating Strings

# %% [markdown]
# You're interested in a stretch of the worm genome that contains part of the rol-6 gene. The sequence you're interested in is `GCACATTCCAATTGTAGacaaattca`, where lowercase letters are non-coding and uppercase letters are coding, as is the format from wormbase.
#
# In the code cell below, store this sequence as a variable of the correct type.

# %%
# Store your gene rol-6 gene sequence here.

# %% [markdown]
# ## Subsetting Strings
#
# Get familiar with your sequence...
#
# In the code cell below, print the 4th nucleotide (i.e. the `C` after `A`). (Hint: how does python count?)
#
# Then print the first and the last (Hint: there's a handy way to start at the end of your sequence. See if you can find it online).

# %%
# What's the 4th nucleotide in your sequence? 

# The first nucleotide? 

# The last nucleotide?

# %% [markdown]
# Now, we want to subset multiple bases at a time. By indexing the variable above, print the sequence `CAATTGTAGacaaattca`.

# %%
# Subset your rol-6 sequence to generate the sequence: `CAATTGTAGacaaattca`

# %% [markdown]
# How many nucleotides are in the original sequence?

# %%
# Print how many nucleotides are in your sequence.

# %% [markdown]
# Bob Johnston, the molecular biology professor, tells you that most worms have a G instead of a C (i.e., GCACATT**G**CAATTGTAGacaaattca instead of GCACATT**C**CAATTGTAGacaaattca). You want to modify your sequence, but recall that you can't just change a single position in our string variable.
#
# Try to change that C to a G in your original sequence using indexing. It should give you an error.

# %%
# Try to change that C in your original sequence to a G

# %% [markdown]
# Instead, you need to store your sequence as a different data type - one that lets you change the value at a single position. Can you recall which data type lets you edit based on position?

# %%
# Remember how to comment your code? 
# Add a comment in this code cell noting which data type lets you change the value at a single position.

# %% [markdown]
# There is a handy way to convert a string directly to a list - see if you can find it online, and then write your best attempt at this conversion in the code block below.

# %%
# Convert your string to a list here

# %% [markdown]
# Now that you have your sequence stored as a list, modify it so your new sequence has a G instead of a C. Code this in the code cell below.

# %%
# Modify your sequence here

# %% [markdown]
# ## Using built-in functions to convert list to string

# %% [markdown]
# Now that your DNA sequence is stored as a list and you've changed your C to a G, we want to put it back into a string. (There are reason you might want your DNA in a list, in a string, or in another data type; we are sticking with list because that's how you'll work with your DNA sequence in the CRISPR design steps.)
#
# We learned a few built-in functions - functions that are automatically included in python and you can use any time. Go back to Intro to Python and pick which built-in function will best allow you to convert your list to a string. Convert your list back to a string in the code block below.

# %%
# Convert your list to a string here

# %% [markdown]
# ## Using built-in functions to modify strings

# %% [markdown]
# You'd like to share this DNA sequence with a friend, but you don't want them to know which nucleotides are coding or noncoding. In the code cell below, store your sequence as a new variable that doesn't indicate nucleotide function with letter case.

# %%
# Store your sequence as a new variable here

# %% [markdown]
# ## "Modifying" strings another way
#
# Sometimes, there's an easier way to modify strings, rather than converting it to a list first. In the code cell below, use string indexing to change the same base as above from a 'C' to a 'G'. Recall, you won't be able to just modify the base at a specific position. Instead, try grabbing the bases you want _unchanged_ and adding the base in that you want to change.

# %%
# Use string indexing to make the same edit as above

# %% [markdown]
# # Data types: dictionaries and lists

# %% [markdown]
# ## Choosing a data type
# You're investigating a set of worm's genes and want to tell a collaborator which trait you think each is associated with. Which data type do you use? Why?

# %%
# Use a code comment to tell us which data type and why

# %% [markdown]
# ## Building, searching, and modifying a dictionary
# Here are some worm genes (on the left) and their known phenotypes (on the right). Make this into the datatype you chose (use the correct variable types for each), and store it with an informative variable name.
#
# *   lin (lineage defective)
# *   unc (uncoordinated)
# *   sur (suppressor of ras)
# *   bli (blister)
# *   ste (unknown)

# %%
# Build your data type for the genes and phenotypes here

# %% [markdown]
# Now Bob Johnston wants to know what phenotype is associated with the gene `bli`. Can you quickly find it to tell him?

# %%
# Code to show bli's phenotype here

# %% [markdown]
# One of Bob's grad students looked at your list and told you that `ste` causes worms to be sterile. Modify your data type to reflect this new information.

# %%
# Modfy your data type here

# %% [markdown]
# The grad student also offers you a couple more genes:
# *   let (lethal)
# *   rol (roller)
# *   egl (egg-laying defective)
#
# Add these to your data type.

# %%
# Add those genes to your data type here

# %% [markdown]
# The step you took to update the phenotype for `ste` might look similar to the step you did to add those other three genes.
#
# Can you explain why this is the same, even though it had two different outcomes (i.e., updating vs. adding)?

# %%
# Write your answer as a code comment here

# %% [markdown]
# Print how many genes are included in your data type. Use the hint below if needed.

# %%
#@title <font color='green'>Click here for a hint</font>
#Hint: think about the 'length' of your data type.

# %%
# Print how many genes are in your data type here

# %% [markdown]
# You're curious about the number of common variants in each gene (note: these numbers are made up). Make a separate data type for these, and make sure your variables are the correct data type within it.
# *   lin (2)
# *   unc (4)
# *   sur (3)
# *   bli (2)
# *   ste (3)
# *   let (4)
# *   rol (1)
# *   egl (1)

# %% [markdown]
# # Building a codon table

# %% [markdown]
# You want to convert your DNA sequence into an amino acid sequence (i.e., translation). To do so, you need to use the codon table. Here's an example - you might have seen these in your textbooks or on wikipedia before. We see here the codons that code for each amino acid (e.g., UGU and UGC give Cystine; UGA, UAA, and UAG give Stop).
#
# What data structure makes sense for the codon table? Why?

# %%
# Describe your choice of a data structure and why here as a comment

# %% [markdown]
# ![Screen Shot 2021-09-24 at 12.24.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# Recall that multiple codons can yield the same amino acid (e.g., both CAC and CAT code for Histidine). We specifically want a data structure that allows us to check what amino acid a given codon encodes. Given this, should our structure be `{ codon : amino acid }` or `{ amino acid : codon }`?

# %%
# Write your explanation for your data structure's format here as a comment

# %% [markdown]
# Once you've answered these questions, you're ready to build your codon table. Try to find one online that's in the format you prefer (paying attention to which information is the key and which is the value). When you find one you like, paste it into the code block below so you can use it for the next couple of questions. Make sure both the `key` and the `value` are in the variable type you want, and name it something informative. (You can write the full amino acid (Serine), its abbreviation (Ser), or its letter (S)). You can also make one yourself, but this will likely take much longer.
#
# (If you're unsure about this, read over the appropriate sections of the Intro to Python notebook and let a TA know if you have questions.)

# %%
# Paste your codon table from the internet here

# %% [markdown]
# The codon table as written should allow you to use the `key` (codon) to see which `value` (amino acid) it encodes. Practice using the key to look up the value. What amino acid is coded by TCA? TCC? TTA? TTG?

# %%
# Code to show which amino acid is coded by...
# TCA 

# TCC

# TTA 

# TTG

# %% [markdown]
# We might also want to see all the codons that can code for a given amino acid. Try looking up serine (S). It should give you an error.

# %%
# Code to see which amino acids give you serine

# %% [markdown]
# Next week, we'll learn how to invert this structure into a format where you can look up an amino acid to find *all* the codons that code for it. Have a great week!
